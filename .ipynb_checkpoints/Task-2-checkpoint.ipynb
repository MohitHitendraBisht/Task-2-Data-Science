# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set()

# %%
telecom = pd.read_csv(r"C:/Users/Mohit/Task-2 Data Science/telecom.csv")

# %%
telecom.head(n=2)
# Out:
#   Age_group  Gender Mobile_network  Mobile_data_performance  \
# 0      0-18  Female             3G                      3.0
# 1  45 above    Male             4G                      4.0
#
#    Call_SMS_facility  Network_issues Most_liked_facility  \
# 0                4.0             3.0             Calling
# 1                5.0             4.0         Mobile Data
#
#   Facility_needs_improvement
# 0                 Mobile Data
# 1                        None

# %%
telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age_group                    15 non-null     object
#  1   Gender                       15 non-null     object
#  2   Mobile_network               15 non-null     object
#  3   Mobile_data_performance      15 non-null     float64
#  4   Call_SMS_facility            15 non-null     float64
#  5   Network_issues               15 non-null     float64
#  6   Most_liked_facility          15 non-null     object
#  7   Facility_needs_improvement   15 non-null     object
# dtypes: float64(3), object(5)
# memory usage: 1.1+ KB

# %%
display(telecom['Age_group'].value_counts().head(10))
age=telecom['Age_group'].value_counts()

display(telecom['Gender'].value_counts().head(10))
gender=telecom['Gender'].value_counts()

display(telecom['Most_liked_facility'].value_counts().head(10))
most_liked=telecom['Most_liked_facility'].value_counts()

display(telecom['Mobile_network'].value_counts().head(10))
mobile_network=telecom['Mobile_network'].value_counts()
# Out:
# 45 above    4
# 18-25       4
# 0-18        4
# 25-45       3
# Name: Age_group, dtype: int64
# Male      8
# Female    4
# Other     3
# Name: Gender, dtype: int64
# Mobile Data    9
# Calling        4
# SMS            2
# Name: Most_liked_facility, dtype: int64
# 4G    5
# 2G    5
# 5G    4
# 3G    1
# Name: Mobile_network, dtype: int64

# %%
plt.rcParams['figure.figsize']=[13,7]
sns.barplot(x=age.index,y=age.values)
plt.xticks(rotation=90)
plt.title('Enquiries by age group')
plt.show()

# %%
plt.rcParams['figure.figsize']=[13,7]
sns.barplot(x=mobile_network.index,y=mobile_network.values)
plt.title('Mobile Network Type')
plt.show()

# %%
plt.rcParams['figure.figsize']=[13,7]
sns.barplot(x=Most_liked_facility.index,y=Most_liked_facility.values)
plt.title('Most liked facility')
plt.show()

# %%
mobile_data=telecom['Mobile_data_performance'].value_counts()
sns.lineplot(x=mobile_network.index,y=mobile_data.index,color='green')
# plt.xticks(rotation=90)
plt.title('Mobile data performance')
plt.show()
